# %%
import pandas as pd
df = pd.read_csv('world_population.csv')
#Setting and Resetting the Index
rank_as_index=df.set_index("Rank")
print(rank_as_index.head())
print('\n')
rank_as_index = rank_as_index.reset_index()
print(rank_as_index.head())
# Out:
#      CCA3         Country           Capital Continent  2022 Population  \
# Rank
# 36    AFG     Afghanistan             Kabul      Asia       41128771.0
# 138   ALB         Albania            Tirana    Europe        2842321.0
# 34    DZA         Algeria           Algiers    Africa       44903225.0
# 213   ASM  American Samoa         Pago Pago   Oceania          44273.0
# 203   AND         Andorra  Andorra la Vella    Europe          79824.0
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 36         38972230.0       33753499.0       28189672.0       19542982.0
# 138         2866849.0        2882481.0        2913399.0        3182021.0
# 34         43451666.0       39543154.0       35856344.0       30774621.0
# 213           46189.0          51368.0          54849.0          58230.0
# 203           77700.0          71746.0          71519.0          66097.0
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# Rank
# ...

# %%
#Selecting Certain Rows and columns
dfcca3=df.set_index("CCA3")
select_1_row=dfcca3.loc["JAM"]
print(select_1_row)
# Out:
# Rank                                     139
# Country                              Jamaica
# Capital                             Kingston
# Continent                      North America
# 2022 Population                    2827377.0
# 2020 Population                    2820436.0
# 2015 Population                    2794445.0
# 2010 Population                    2733896.0
# 2000 Population                    2612205.0
# 1990 Population                    2392030.0
# 1980 Population                    2135546.0
# 1970 Population                    1859091.0
# Area (km²)                           10991.0
# Density (per km²)                        NaN
# Growth Rate                              NaN
# World Population Percentage             0.04
# Name: JAM, dtype: object

# %%
select_range_rows=dfcca3=df.loc[3:6]
print(select_range_rows)
# Out:
#    Rank CCA3         Country           Capital      Continent  \
# 3   213  ASM  American Samoa         Pago Pago        Oceania
# 4   203  AND         Andorra  Andorra la Vella         Europe
# 5    42  AGO          Angola            Luanda         Africa
# 6   224  AIA        Anguilla        The Valley  North America
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 3          44273.0          46189.0          51368.0          54849.0
# 4          79824.0          77700.0          71746.0          71519.0
# 5       35588987.0       33428485.0       28127721.0       23364185.0
# 6          15857.0          15585.0          14525.0          13172.0
#
#    2000 Population  1990 Population  1980 Population  1970 Population  \
# 3          58230.0          47818.0          32886.0          27075.0
# 4          66097.0          53569.0          35611.0          19860.0
# 5       16394062.0       11828638.0        8330047.0        6029700.0
# ...

# %%
select_column_range=df.iloc[13:15]
print(select_column_range)
# Out:
#     Rank CCA3     Country Capital      Continent  2022 Population  \
# 13    91  AZE  Azerbaijan    Baku           Asia       10358074.0
# 14   176  BHS     Bahamas  Nassau  North America         409984.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 13              NaN        9863480.0        9237202.0        8190337.0
# 14         406471.0         392697.0         373272.0         325014.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 13        7427836.0        6383060.0        5425317.0     86600.0
# 14         270679.0         223752.0         179129.0     13943.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 13           119.6082       1.0044                         0.13
# 14            29.4043       1.0051                         0.01

# %%
select_both=df.loc[0:12][1:2]
print(select_both)
# Out:
#    Rank CCA3  Country Capital Continent  2022 Population  2020 Population  \
# 1   138  ALB  Albania  Tirana    Europe        2842321.0        2866849.0
#
#    2015 Population  2010 Population  2000 Population  1990 Population  \
# 1        2882481.0        2913399.0        3182021.0        3295066.0
#
#    1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 1        2941651.0        2324731.0     28748.0            98.8702
#
#    Growth Rate  World Population Percentage
# 1       0.9957                         0.04
